# %%
! pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\python311\lib\site-packages (4.8.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\python311\lib\site-packages (from pymongo) (2.6.1)
# WARNING: Ignoring invalid distribution ~ (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ccelerate (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~valuate (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ccelerate (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~valuate (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ccelerate (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~orch (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~valuate (C:\Python311\Lib\site-packages)

# %%
from mongo import MongoDBManager
import os
from dotenv import load_dotenv
import pandas as pd
import matplotlib.pyplot as plt
import re

# %% [markdown]
# # Retrieving data

# %%
load_dotenv()
uri = os.getenv('MONGODB_URI')
database_name = os.getenv('DATABASE_NAME')
mongo_manager = MongoDBManager(uri, database_name)

# %%
documents = mongo_manager.read_all_documents_in_collection_with_GridFS()

# %%
def data_recurcive_length(data):
    total = 0
    try:
        for key in data.keys():
            for profession in data[key].keys():
                for language in data[key][profession].keys():
                    print(f"{key} - {profession} - {language} : {len(data[key][profession][language])}")
                    total += len(data[key][profession][language])
        print(f"Total: {total}")
    except Exception as e:
        print(e)
        print(data[key][profession])

# %%
data_recurcive_length(documents)
# Out:
# US - Accompagnatrice spirituelle ou accompagnateur spirituel - en : 68
# US - Accompagnatrice spirituelle ou accompagnateur spirituel - fr : 18
# US - Accompagnatrice, accompagnateur, musicienne ou musicien dans de petits ensembles - fr : 27
# US - Accompagnatrice, accompagnateur, musicienne ou musicien dans de petits ensembles - en : 2723
# US - Actuaire - en : 108
# US - Adjointe ou adjoint à la recherche - en : 236
# US - Administratrice ou administrateur - fr : 8
# US - Administratrice ou administrateur - en : 1678
# US - Administratrice ou administrateur de contrats - fr : 25
# US - Administratrice ou administrateur de contrats - en : 522
# US - Administratrice ou administrateur de programmes de développement durable - fr : 12
# US - Administratrice ou administrateur de programmes de développement durable - en : 1024
# US - Administratrice ou administrateur de prêts commerciaux - fr : 51
# US - Administratrice ou administrateur de prêts commerciaux - en : 999
# US - Agent ou agente d’approvisionnement et de gestion contractuelle - en : 3460
# US - Agent ou agente d’approvisionnement et de gestion contractuelle - fr : 96
# US - Agente commerciale ou agent commercial, politique ou du service extérieur - fr : 32
# US - Agente commerciale ou agent commercial, politique ou du service extérieur - en : 36
# US - Agente ou agent d'opposition - fr : 22
# US - Agente ou agent d'opposition - en : 204
# US - Agente ou agent d'équité en matière d'emploi - en : 1615
# France - Accompagnatrice spirituelle ou accompagnateur spirituel - fr : 20
# France - Accompagnatrice, accompagnateur, musicienne ou musicien dans de petits ensembles - fr : 1288
# France - Accompagnatrice, accompagnateur, musicienne ou musicien dans de petits ensembles - en : 36
# France - Actuaire - fr : 18
# France - Administratrice ou administrateur - fr : 16
# France - Agent ou agente d’approvisionnement et de gestion contractuelle - fr : 15
# France - Agente commerciale ou agent commercial, politique ou du service extérieur - fr : 3064
# France - Agente commerciale ou agent commercial, politique ou du service extérieur - en : 1096
# France - Agente ou agent d'opposition - fr : 60
# France - Agente ou agent d'opposition - en : 10
# France - Agente ou agent d'équité en matière d'emploi - fr : 15
# France - Agente ou agent d'équité en matière d'emploi - en : 29
# Canada - Agente ou agent communautaire, de développement, de planification, des politiques sociales, de programmation, de recherche - fr : 13
# Canada - Accompagnatrice spirituelle ou accompagnateur spirituel - fr : 101
# Canada - Accompagnatrice spirituelle ou accompagnateur spirituel - en : 23
# Canada - Accompagnatrice, accompagnateur, musicienne ou musicien dans de petits ensembles - fr : 179
# Canada - Accompagnatrice, accompagnateur, musicienne ou musicien dans de petits ensembles - en : 1040
# Canada - Actuaire - fr : 119
# Canada - Actuaire - en : 609
# Canada - Acheteuse ou acheteur - fr : 634
# Canada - Acheteuse ou acheteur - en : 1212
# Canada - Adjointe ou adjoint à la recherche - fr : 705
# Canada - Adjointe ou adjoint à la recherche - en : 907
# Canada - Administratrice ou administrateur - fr : 518
# Canada - Administratrice ou administrateur - en : 1398
# Canada - Administratrice ou administrateur de contrats - fr : 128
# Canada - Administratrice ou administrateur de contrats - en : 1104
# Canada - Administratrice ou administrateur de programmes de développement durable - fr : 91
# Canada - Administratrice ou administrateur de programmes de développement durable - en : 409
# Canada - Administratrice ou administrateur de prêts commerciaux - fr : 77
# Canada - Administratrice ou administrateur de prêts commerciaux - en : 114
# Canada - Agent ou agente d’approvisionnement et de gestion contractuelle - fr : 96
# Canada - Agent ou agente d’approvisionnement et de gestion contractuelle - en : 492
# Canada - Agente commerciale ou agent commercial, politique ou du service extérieur - fr : 479
# Canada - Agente commerciale ou agent commercial, politique ou du service extérieur - en : 1751
# Canada - Agente ou agent d'opposition - fr : 9
# Canada - Agente ou agent d'opposition - en : 15
# Canada - Agente ou agent d'équité en matière d'emploi - fr : 159
# Canada - Agente ou agent d'équité en matière d'emploi - en : 1373
# Total: 32386

# %% [markdown]
# # Formating Datas

# %%
def data_to_sql_format(data):
    data_formated = []
    for country in documents.keys():
        for profession in documents[country].keys():
            for language in documents[country][profession].keys():
                    for data in documents[country][profession][language]:
                        data['country'] = country
                        data['profession'] = profession
                        data['language'] = language
                        data_formated.append(data)
    return data_formated                    
data_formated=data_to_sql_format(documents)
print(len(data_formated))
# Out:
# 37141

# %%
import dedupe

def clear_data(data):
    df=pd.DataFrame(data)
    df = df.applymap(lambda x: tuple(x) if isinstance(x, list) else x)
    df=df.drop_duplicates()
    df.describe()
    # countries = df["country"].drop_duplicates().to_list()
    # professions = df["profession"].drop_duplicates().to_list()
    # languages = df["language"].drop_duplicates().to_list()
    # clear_data={}
    # for country in countries:
    #     for profession in professions:
    #         for lang in languages:
    #             try:
    #                 if country not in clear_data:
    #                     clear_data[country] = {}
    #                 if profession not in clear_data[country]:
    #                     clear_data[country][profession] = {}
                    
    #                 filtered_df = df[(df["language"] == lang) & (df["profession"] == profession) & (df["country"] == country)]
    #                 clear_data[country][profession][lang] = filtered_df.to_dict('records')
    #             except Exception as e:
    #                 print(e)
                
    # return clear_data

data_cleared = clear_data(data_formated)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_45196\3582831003.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: tuple(x) if isinstance(x, list) else x)

# %%
data_recurcive_length(data_cleared)
# Out:
# 'NoneType' object has no attribute 'keys'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 4, in data_recurcive_length(data)
#       3 try:
# ----> 4     for key in data.keys():
#       5         for profession in data[key].keys():
#
# AttributeError: 'NoneType' object has no attribute 'keys'
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data_recurcive_length(data_cleared)
#
# Cell In[5], line 12, in data_recurcive_length(data)
#      10 except Exception as e:
#      11     print(e)
# ---> 12     print(data[key][profession])
#
# UnboundLocalError: cannot access local variable 'key' where it is not associated with a value

# %% [markdown]
# # Visualizing Data

# %%
df = pd.DataFrame(data_formated)
df.describe()
# Out:
#                positionTitle companyName      location salaryInfoAndJobType  \
# count                  37141       37141         37141                37141
# unique                 14897        7710          6530                 5413
# top     Office Administrator              Montréal, QC            Full-time
# freq                     450         291           924                 4084
#
#        description datePosted salary jobType shiftAndSchedule jobBenefits  \
# count        37141      36119  37141   37141            37141       37141
# unique       11539         61   3233     322              584        3164
# top                                       []                           []
# freq           296       4487  17621    8222            26759       17670
#
#        updatedDate country                                         profession  \
# count        37141   37141                                              37141
# unique          15       3                                                 17
# top     2024-09-13  Canada  Agente commerciale ou agent commercial, politi...
# freq          9015   15684                                               6458
#
#        language
# count     37141
# unique        2
# top          en
# freq      27069

# %%
df[df['shiftAndSchedule'] != ''].describe()
# Out:
#                positionTitle companyName      location salaryInfoAndJobType  \
# count                  10382       10382         10382                10382
# unique                  5546        2772          2569                 2209
# top     Office Administrator        PHSA  Montréal, QC            Full-time
# freq                     220         187           278                  864
#
#                                               description datePosted salary  \
# count                                               10382      10071  10382
# unique                                               3377         61   1356
# top     POSTE AVEC BEAUCOUP DE DÉPLACEMENT\n\nSERVICES...
# freq                                                   44       1024   3674
#
#        jobType    shiftAndSchedule jobBenefits updatedDate country  \
# count    10382               10382       10382       10382   10382
# unique     129                 583        1603          12       2
# top             [Monday to Friday]          []  2024-09-13  Canada
# freq      1890                1333        3220        3213    6156
#
#                                profession language
# count                               10382    10382
# unique                                 17        2
# top     Administratrice ou administrateur       en
# freq                                 1725     8309

# %%
df[:5]
# Out:
#                                        positionTitle  \
# 0             Overnight Cabin Supervisor-SFO Airport
# 1   Chaplain - N/E - New River Valley Medical Center
# 2  Bethany Christian Church Residency - Washingto...
# 3         Groups Director/Pastor (Plainfield Campus)
# 4                            Personal Care Attendant
#
#                           companyName  \
# 0                     G2 Secure Staff
# 1                     Carilion Clinic
# 2                  Leadership Pathway
# 3  Traders Point Christian Church Inc
# 4                            EveryAge
#
#                                             location  \
# 0  780 South Airport Boulevard, San Francisco, CA...
# 1         2900 Lamb Circle, Christiansburg, VA 24073
# 2                               Washington, IN 47501
# 3           2002 Stafford Road, Plainfield, IN 46168
# 4                                Lexington, NC 27292
#
#          salaryInfoAndJobType  \
# 0     $31 an hour - Full-time
# 1
# 2  $1,000 a month - Full-time
# 3                   Full-time
# 4                   Full-time
#
#                                          description  datePosted  \
# 0  G2 Secure Staff is expanding and looking to ad...  2024-09-06
# 1  Provides a ministry of spiritual care and emot...  2024-09-09
# 2  Bethany Christian Church is a growing multi-si...  2024-08-10
# 3  CULTURE & SPIRITUAL LEADERSHIP\n\nTraders Poin...  2024-09-09
# 4  Carolina SeniorCare is a non-profit provider o...  2024-09-09
#
#             salary           jobType  \
# 0                   [an hour , Full]
# 1                                 []
# 2  $1,000 a month   [an hour , Full]
# 3                                 []
# 4                                 []
#
#                              shiftAndSchedule  \
# 0
# 1  [Weekends as needed, Night shift, On call]
# 2
# 3
# 4
#
#                                          jobBenefits updatedDate country  \
# 0  [401(k), 401(k) matching, Dental insurance, Em...  2024-09-09      US
# 1                                                 []  2024-09-11      US
# 2                                                 []  2024-09-09      US
# 3                     [Leadership training provided]  2024-09-11      US
# 4                                                 []  2024-09-11      US
#
#                                           profession language
# 0  Accompagnatrice spirituelle ou accompagnateur ...       en
# 1  Accompagnatrice spirituelle ou accompagnateur ...       en
# 2  Accompagnatrice spirituelle ou accompagnateur ...       en
# 3  Accompagnatrice spirituelle ou accompagnateur ...       en
# 4  Accompagnatrice spirituelle ou accompagnateur ...       en

# %%
df = df.applymap(lambda x: tuple(x) if isinstance(x, list) else x)
df = df.drop_duplicates()

df = df[((df['positionTitle'] != '') & (df['description'] != '')) | df['positionTitle'] != '']
"""
df['jobType'] = df.apply(
    lambda x: tuple(list(x['jobType']) + list(x['salary'])) 
    if not re.search(r'\d+', str(x['salary'])) 
    else x['jobType'], 
    axis=1
)
"""
"""
df['salary'] = df['salary'].map(
    lambda x: '' 
    if not re.search(r'\d+', str(x))
    else x
)

df['salary'] = df.apply(
    lambda x: str(x['salary']+"-"+str(list(x['jobType'])[0]) )
    if not re.search(r'\d+', str(list(x['jobType'])[0])) 
    else str(x['salary']), 
    axis=1
)
professions[5:7]

df['jobType'] = df['jobType'].map(
    lambda x: '' 
    if not re.search(r'\d+', str(x))
    else x
)
"""
df.describe()
# Out:
# C:\Users\gueid\AppData\Local\Temp\ipykernel_35992\3406113667.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: tuple(x) if isinstance(x, list) else x)
#                positionTitle companyName      location salaryInfoAndJobType  \
# count                  32011       32011         32011                32011
# unique                 12553        6917          5995                 4831
# top     Office Administrator        PHSA  Montréal, QC            Full-time
# freq                     445         251           778                 3414
#
#        description datePosted salary jobType shiftAndSchedule jobBenefits  \
# count        32011      31158  32011   32011            32011       32011
# unique       10075         59   2821     300              546        2868
# top                                       ()                           ()
# freq           214       3914  14760    7241            22873       15265
#
#        updatedDate country                                         profession  \
# count        32011   32011                                              32011
# unique          14       3                                                 14
# top     2024-09-13  Canada  Agente commerciale ou agent commercial, politi...
# freq          8711   13563                                               6434
#
#        language
# count     32011
# unique        2
# top          en
# freq      23955

# %%
for column in df.columns:
    print(column)
# Out:
# positionTitle
# companyName
# location
# salaryInfoAndJobType
# description
# datePosted
# salary
# jobType
# shiftAndSchedule
# jobBenefits
# updatedDate
# country
# profession
# language

# %%
df[df['positionTitle'].str.contains('rn', case=False)==True]['positionTitle'].tolist()
# Out:
# ['Overnight Cabin Supervisor-SFO Airport',
#  'Phlebotomist Technician (Morning Shift)',
#  'All-Source Intelligence Analyst Journeyman',
#  'Direct Support Professional - Overnights',
#  'Certified Nursing Assistant (CNA) Afternoons',
#  'Instructional Designer (Digital Learning)',
#  '10 hr schedule Afternoon/Midnight split Shelter Specialist',
#  'Overnight Relief Crisis Intervention Specialist (QMHP)',
#  'Resident Coordinator - PRN-Day and Swing Shift',
#  'Patient Care RN in the Acute Department',
#  'Northern & Western Montana Outreach Specialist (Havre)',
#  'Veteran Care Coordinator-RN',
#  'Bilingual PRN Early Childhood Instructor',
#  'BRONSON BATTLE CREEK LICENSED PRACTICAL NURSE (LPN) PRN VARIABLE HOURS',
#  'Horn Teaching Artist - North Side',
#  '10 hr schedule Afternoon/Midnight split Shelter Specialist',
#  'All-Source Intelligence Analyst Journeyman',
#  'Overnight Relief Crisis Intervention Specialist (QMHP)',
#  'Direct Support Professional (Part-time Sleep Overnights)',
#  'Assistant Director, Graduate Technical Programs Career Advisor, Cornell Tech (NYC)',
#  'Geriatric Health Care Manager PRN',
#  'Security Officer 16-Hour Part Time Morning Position',
#  'All-Source Intelligence Analyst Journeyman',
#  'Federal Workday Learning Lead',
#  'LPN/RN Needed For All Shifts Now - Norwood, MA',
#  'Social Emotional Learning Specialist',
#  'Federal Workday Learning Lead',
#  'RN, Family Care',
#  'Bilingual PRN Early Childhood Instructor',
#  'Assistant Director, Graduate Technical Programs Career Advisor, Cornell Tech (NYC)',
#  'PRN - Medical Scribe II',
#  'Direct Support Professional (Part-time Sleep Overnights)',
#  '10 hr schedule Afternoon/Midnight split Shelter Specialist',
#  'Instructional Designer (Digital Learning)',
#  'Assistant Director, Graduate Technical Programs Career Advisor, Cornell Tech (NYC)',
#  'Direct Support Professional (Part-time Sleep Overnights)',
#  'Direct Support Staff - (DSS), Morning Shifts',
#  'Security Officer 16-Hour Part Time Morning Position',
#  'Overnight Relief Crisis Intervention Specialist (QMHP)',
#  'OVERNIGHT Behavioral Health Technician',
#  '10 hr schedule Afternoon/Midnight split Shelter Specialist',
#  'Box Office & Afternoon Administrative Assistant',
#  'Federal Workday Learning Lead',
#  'Registered Nurse (RN): Hospital (Med-Surg)',
#  'Direct Support Staff - (DSS), Morning Shifts',
#  'Direct Support Staff - (DSS), Morning Shifts',
#  'RN, Family Care',
#  'Direct Support Staff - (DSS), Morning Shifts',
#  'RN, Family Care',
#  'Northern & Western Montana Outreach Specialist (Havre)',
#  'Attendance & Registration Specialist - Katherine Mecham Barney Elementary School',
#  'Direct Support Professional - Overnights',
#  'Direct Support Professional (Part-time Sleep Overnights)',
#  'Federal Workday Learning Lead',
#  'Overnight Relief Crisis Intervention Specialist (QMHP)',
#  'Attendance & Registration Specialist - Katherine Mecham Barney Elementary School',
#  'Overnight Front Desk Manager',
#  'All-Source Intelligence Analyst Journeyman',
#  'Direct Support Professional - Overnights',
#  'Veteran Care Coordinator-RN',
#  "Sales Associate/ Internet Sales - GET PAID WHAT YOU'RE WORTH!",
#  'Associate Attorney',
#  'Security Officer 16-Hour Part Time Morning Position',
#  'Security Officer 16-Hour Part Time Morning Position',
#  'Patient Care RN in the Acute Department',
#  'Certified Nursing Assistant (CNA) Afternoons',
#  'Veteran Care Coordinator-RN',
#  'DSP 10pm-6am (overnights)',
#  'Direct Support Professional - Awake Overnight',
#  'All-Source Intelligence Analyst Journeyman',
#  'Direct Support Professional (Part-time Sleep Overnights)',
#  'Camp Counselor - Wilderness Instructor - still hiring!',
#  'PRN - Medical Scribe II',
#  'Surgical Technician PRN',
#  'All-Source Intelligence Analyst Journeyman',
#  'Direct Support Professional (Part-time Sleep Overnights)',
#  'Program Assistant (Seminars & Journalism)',
#  'Social Emotional Learning Specialist',
#  'Federal Workday Learning Consultant',
#  'Assistant Director, Graduate Technical Programs Career Advisor, Cornell Tech (NYC)',
#  'Cardiovascular Special Procedures Tech (CST), Cath Lab, PRN, Days',
#  'Clinical Research Coordinator, RN',
#  'PRN Research Assistant',
#  'Project Administrator, International Post Operations',
#  'PRN Office Administrator',
#  'Project Administrator, International Post Operations',
#  'Early Learning Director Operation Admin',
#  "Business Operations Administrator – City Attorney's Office",
#  'Project Administrator, International Post Operations',
#  'Returns Administrator',
#  'Returns Administrator',
#  'Manager, Governments Contracts',
#  'Government Contracts Administrator',
#  'Contract Specialist (Government)',
#  'Local Government Contract Expert',
#  'Government Property Contract Specialist',
#  'Local Government Contract Expert',
#  'Grants Internal Controls and Compliance Consultant',
#  'Government Contract Administrator',
#  'Government Contract Specialist',
#  'Concessions Contract Administrator - Denver International Airport',
#  'Government Contract Specialist',
#  'ASSOCIATE GOVERNMENTAL PROGRAM ANALYST',
#  'Office of Global Learning, Cornell University Programming Coordinator',
#  'Assistant/Associate/Full Professor - Office of Educational Programs, McGovern Medical School',
#  'ALUMNI EXTERNAL REL SPEC 2',
#  'Office of Global Learning, Cornell University Programming Coordinator',
#  'ALUMNI EXTERNAL REL SPEC 2',
#  'Teaching & Learning Coordinator - Math',
#  'Turnover Lead',
#  'Food, Health, And Safety Program Coordinator- Early Learning Center',
#  'Program Assistant – Cornell K. Lisa Yang Center for Wildlife Health',
#  'ASSOCIATE GOVERNMENTAL PROGRAM ANALYST',
#  'Technical Project Manager, Government Operations Recovery Initiative (Gov Ops), Office of the City Administrator (1825)',
#  'LEARN TO WORK COORDINATOR',
#  'LEARN TO WORK COORDINATOR',
#  'Program Assistant – Cornell K. Lisa Yang Center for Wildlife Health',
#  'Learning Specialist',
#  'International Baccalaureate (IB) Primary Years Program (PYP) Coordinator',
#  'Teaching & Learning Coordinator - Math',
#  'Technical Project Manager, Government Operations Recovery Initiative (Gov Ops), Office of the City Administrator (1825)',
#  'Specialist, Learning & Development',
#  'Learning Systems Administrator',
#  'Alternatives Operations Analyst',
#  'GOVERNMENT OPERATIONS CONSULTANT III',
#  'Assistant Director Department Operations, Internal Medicine',
#  'Registered Nurse RN Float Pool',
#  'Business Administrator, Wharton External Affairs',
#  'Learning and Development Administrator II',
#  'CHIEF OF PLANNING, DEVELOPMENT AND MODERNIZATION',
#  'Senior Associate Learning & Development',
#  'RN Registered Nurse Float Pool',
#  'Governance & Research Administration Support',
#  'Business Administrator, Wharton External Affairs',
#  'Learning and Development Specialist',
#  'Sr Finance Partner, Vaccines US Government Contracting',
#  'Account Manager, Government Contracting (State, Local, Education)',
#  'ASSOCIATE GOVERNMENTAL PROGRAM ANALYST',
#  'Journeyman Level Contracts Support Specialist',
#  'Government Contract Research Specialist',
#  'Account Manager, Government Contracting (State, Local, Education)',
#  'Contracts Manager - International Development',
#  'Government Business Development Manager',
#  'Vice President - Government GSA Business & Public Relations',
#  'Government Contract Research Specialist',
#  'Construction Contract Administrator (Government Projects)',
#  'Account Manager, Government Contracting (State, Local, Education)',
#  'Government Subcontract Specialist',
#  'Government Subcontract Specialist',
#  'Senior Sales Executive, Government',
#  'Office Manager (Northern Virginia)',
#  'Construction Contract Administrator (Government Projects)',
#  'Business and Development Professional – Government Contracts',
#  'Account Manager, Government Contracting (State, Local, Education)',
#  'Government Contract Research Specialist',
#  'Government Business Development Manager',
#  'AVP Foundation and Government Support',
#  'Development and Modernization Director',
#  'Construction Contract Administrator (Government Projects)',
#  'Business and Development Professional – Government Contracts',
#  'VP, Sales (Eastern US)',
#  'AVP Foundation and Government Support',
#  'Journeyman Level Contracts Support Specialist',
#  'ASSOCIATE GOVERNMENTAL PROGRAM ANALYST',
#  'ASSOCIATE GOVERNMENTAL PROGRAM ANALYST',
#  'Construction Contract Administrator (Government Projects)',
#  'Government Business Development Manager',
#  'Office Manager (Northern Virginia)',
#  'Journeyman Level Contracts Support Specialist',
#  'Construction Contract Administrator (Government Projects)',
#  'Government & Public Sector (GPS) Compliance Associate Director',
#  'Office Manager (Northern Virginia)',
#  'Director & Senior Counsel, Government Contracts Compliance',
#  'Government Contract Research Specialist',
#  'ASSOCIATE GOVERNMENTAL PROGRAM ANALYST',
#  'Office Manager (Northern Virginia)',
#  'AVP Foundation and Government Support',
#  'Journeyman Level Contracts Support Specialist',
#  'Government Subcontract Specialist',
#  'Government Contract Research Specialist',
#  'Senior Sales Executive, Government',
#  'Development and Modernization Director',
#  'Journeyman Level Contracts Support Specialist',
#  'Government Contract Research Specialist',
#  'Account Manager, Government Contracting (State, Local, Education)',
#  'Office Manager (Northern Virginia)',
#  'Apprenti Mobilité Internationale H/F',
#  'Apprenti Mobilité Internationale H/F',
#  'Apprenti Mobilité Internationale H/F',
#  'Apprenti Mobilité Internationale H/F',
#  'Apprenti Mobilité Internationale H/F',
#  'Apprenti Mobilité Internationale H/F',
#  'Apprenti Mobilité Internationale H/F',
#  'Apprenti Mobilité Internationale H/F',
#  'Director, Government Relations',
#  'Sr. CBRN/CWMD SME II',
#  'Senior Assistant Commonwealth Attorney',
#  "Senior Assistant Commonwealth's Attorney",
#  'Assistant County Attorney III',
#  "Associate Commonwealth's Attorney",
#  'Assistant County Attorney III',
#  'Assistant County Attorney III',
#  'Senior Assistant Commonwealth Attorney',
#  "Associate Commonwealth's Attorney",
#  'Assistant Commonwealth Attorney III',
#  "Associate Commonwealth's Attorney",
#  'Senior Assistant Commonwealth Attorney',
#  'Director, Government Affairs',
#  'Government Relations and Operations Manager',
#  'Director, Government Affairs',
#  'Director, Government Affairs',
#  'Assistant County Attorney III',
#  "Senior Assistant Commonwealth's Attorney",
#  'Assistant Commonwealth Attorney III',
#  'Development and Modernization Director',
#  'Government Relations and Operations Manager',
#  "Senior Assistant Commonwealth's Attorney",
#  'Assistant Commonwealth Attorney III',
#  'Director, Government Affairs',
#  "Associate Commonwealth's Attorney",
#  'Government Relations and Operations Manager',
#  "Senior Assistant Commonwealth's Attorney",
#  'Assistant Commonwealth Attorney III',
#  'Government Relations and Operations Manager',
#  'Development and Modernization Director',
#  'International Student Advisor',
#  'External Relations Officer',
#  'International Student Programming Coordinator',
#  'Intergovernmental Relations Officer',
#  'External Relations Officer',
#  'Development Assistant, External Relations',
#  'Program Coordinator, Cultural Learning Communities',
#  'Senior Development Officer, National and International Outreach',
#  'Senior Learning and Impact Officer',
#  'Records Training Specialist (Learning and Development Specialist 2)',
#  'Probation/Parole Officer (2-Anson, 3-Cumberland, 4-Harnett, 2-Hoke, 2-Moore, 2-Montgomery)',
#  'Learning and Development Manager – Office of Human Resources',
#  'Senior Development Officer, National and International Outreach',
#  'Policy Advisor, International Justice',
#  'International Student Programming Coordinator',
#  'International Student Support Manager',
#  'Senior Director, Work Based Learning, Student Pathways',
#  'Government Contracts Manager',
#  'Director, Externships and Employment',
#  'Sr. Manager for External Relations',
#  'Associate Faculty Pool, International Education division (PT Faculty)',
#  'Chief Online Learning Officer',
#  'Data Governance Officer',
#  'Director, Externships and Employment',
#  'Development Assistant, External Relations',
#  'International Student Advisor',
#  'Executive Assistant to the Vice President of Learning and Student Success',
#  'Records Training Specialist (Learning and Development Specialist 2)',
#  'Director of Outdoor Programs and Recreation and Assistant Director of Student Experiential Learning',
#  'Supervisory International Relations Officer',
#  'Data Governance Officer',
#  'Sr. Manager for External Relations',
#  'Supervisory International Relations Officer',
#  'Zero Trust Policy and Governance Specialist',
#  'Internal Communication and Engagement Manager',
#  'Program Coordinator, Cultural Learning Communities',
#  'Policy Advisor, International Justice',
#  'Vice President, Work-Based Learning',
#  'Internal Communication and Engagement Manager',
#  'Associate Director, Transfer Advising, Office of International Programs (E)',
#  'Registered Nurse (RN) | Dyersville | PT Nights',
#  'International Grants Director',
#  'Probation/Parole Officer (2-Anson, 3-Cumberland, 4-Harnett, 2-Hoke, 2-Moore, 2-Montgomery)',
#  'International Grants Director',
#  'Director of Outdoor Programs and Recreation and Assistant Director of Student Experiential Learning',
#  'Executive Assistant to the Vice President of Learning and Student Success',
#  'OCI Internal Control Officer',
#  'Director - Government & Community Relations',
#  'Director - Government & Community Relations',
#  'Zero Trust Policy and Governance Specialist',
#  'International Student Programming Coordinator',
#  'Associate Learning and Impact Officer',
#  'International Student Support Manager',
#  'Assistant Director of Fraternity & Sorority Life (Community Development & Belonging)',
#  'Associate Faculty Pool, International Education division (PT Faculty)',
#  'Associate Director, Transfer Advising, Office of International Programs (E)',
#  'Government Contracts Manager',
#  'Evaluation and Learning Officer',
#  'International Corporate Legal Paralegal',
#  'Senior Learning and Impact Officer',
#  'Intergovernmental Relations Officer',
#  'Supervisory International Relations Officer',
#  'Evaluation and Learning Officer',
#  'Associate Learning and Impact Officer',
#  'Supervisory International Relations Officer',
#  'Assistant Director of Fraternity & Sorority Life (Community Development & Belonging)',
#  'Accompagnant éducatif et social H/F en INTERNAT',
#  'Accompagnant Educatif et Social en internat',
#  '2 Accompagnants Educatifs et Sociaux en internat — H/F',
#  "Conseiller local d'insertion - MDS de Lagny-sur-Marne F/H",
#  'Accompagnant Educatif et Social en alternance (PARIS 13) H/F',
#  'Accompagnant Educatif et Social/AMP OU Moniteur Educateur (H/F) à temps plein en CDI/ CAP CORNELY',
#  'Accompagnant Educatif et Social en alternance (PARIS 13) H/F',
#  'Chauffeur accompagnateur scolaire 94 VAL DE MARNE H/F',
#  'Accompagnant Educatif et Social en internat',
#  'Accompagnateur Bus (H/F) Accueil de Loisirs Fournet Luisans CDI',
#  'Accompagnant Educatif et Social en alternance (PARIS 13) H/F',
#  'Accompagnateur Bus (H/F) Accueil de Loisirs Fournet Luisans CDI',
#  'Accompagnant Educatif et Social (H/F) – CDI – PORNIC',
#  '2 Accompagnants Educatifs et Sociaux en internat — H/F',
#  'Chauffeur scolaire H/F BONNEUIL SUR MARNE (94) ET AUX ALENTOURS',
#  'Accompagnant Educatif et Social en alternance (PARIS 13) H/F',
#  'Accompagnant Educatif et Social H/F Alternance Bouches-Du-Rhône (13)',
#  'Chauffeur accompagnateur scolaire 94 VAL DE MARNE H/F',
#  'Accompagnant Educatif et Social ou AMP F/H – CDI FH TAVERNY',
#  'Accompagnant éducatif et social H/F en INTERNAT',
#  'Accompagnateur Bus (H/F) Accueil de Loisirs Fournet Luisans CDI',
#  "Conseiller local d'insertion - MDS de Lagny-sur-Marne F/H",
#  "Conseiller local d'insertion - MDS de Lagny-sur-Marne F/H",
#  'Accompagnants(es) Educatif et Social (AES) d’internat',
#  'Customer Journey Expert - H/F',
#  'Customer Journey Expert - H/F',
#  'Alternance - Agent exploitation transport F/H',
#  'ALTERNANT ASSISTANT MARKETING ET COMMUNICATION – ALTERNANCE (H/F)',
#  'Gestionnaire de projet international (H/F)',
#  'CPAM - Alternance - Assistant de Direction H/F - 93',
#  "Alternant - Agent d'Exploitation (F/H) à Lille",
#  'Assistant RH en alternance H/F',
#  'chef de projet en alternance HF',
#  'Agent de recouvrement en alternance H/F - Gennevilliers',
#  'chef de projet en alternance HF',
#  'Chargé ADV international (H/F)',
#  "ALTERNANT TECHNICIEN SURETÉ EN BUREAU D'ÉTUDES",
#  'Alternant Gestionnaire Administratif F/H',
#  'Chargé ADV international (H/F)',
#  'Assistant chef de projet international - H/F',
#  'ALTERNANT PRÉVENTEUR SANTÉ SÉCURITÉ H/F',
#  'Supply & Procurement Strategy Intern',
#  'ALTERNANCE TECHNICIEN EN SYSTÈMES SURETÉ',
#  'Alternance - Chargé.e de mission QSE F/H',
#  'Alternant Gestionnaire Administratif F/H',
#  'Chargé de projet modernisation des process MDPH (H/F)',
#  'Chargé administratif du service relations internationales F/H',
#  'Gestionnaire Service Clients International H/F',
#  'ALTERNANCE - ASSISTANT(E) CHEF DE CHANTIER (HF) - ...',
#  'Assistant chef de projet international - H/F',
#  "Acheteur - contrat d'alternance H/F",
#  'AGS Le Mans - Commercial Chargé de Clientèle Internationel',
#  'Agent de Transit Maritime (F/H) - alternant',
#  'Assistant(e) gouvernant(e) (H/F)',
#  'Assistant de direction en alternance (Courbevoie - 92) H/F',
#  'Assistant développement commercial et marketing digital - Stage / Alternance (min. 4 mois)',
#  'Chargé administratif du service relations internationales F/H',
#  'Gestionnaire fournisseurs achats H/F',
#  'Chargé de recrutement (alternance) F/H',
#  'Conseiller ou Conseillère en économie sociale et familiale - VAIRES SUR MARNE',
#  'RESPONSABLE COMMUNICATION INTERNE',
#  'Agent de voyage (alternance) - H/F',
#  'Gestionnaire Service Clients International H/F',
#  'ALTERNANT PRÉVENTEUR SANTÉ SÉCURITÉ H/F',
#  'Chargé de la qualité - Alternance (H/F)',
#  'Agent de voyage (alternance) - H/F',
#  'Assistant(e) gouvernant(e) (H/F)',
#  "Chargé d'Etudes Inclusion numérique en Alternance (H/F)",
#  'Alternant Gestionnaire Administratif F/H',
#  'ALTERNANT CHEF DE PROJET TRANSFORMATION NUMERIQUE H/F',
#  'Assistant de direction en alternance (Courbevoie - 92) H/F',
#  'Manager en Alternance (RH)',
#  "Alternant : Agent(e) centre de relation clients et d'information voyageurs F/H 1",
#  'Alternance Chargé(e) de Sécurité des SI - H/F',
#  'OPTICIEN (NE) BTS OU LICENCE ALTERNANCE',
#  'Agent de recouvrement en alternance H/F - Gennevilliers',
#  'Alternant Agent de transit aérien H/F',
#  'ALTERNANT PRÉVENTEUR SANTÉ SÉCURITÉ H/F',
#  'Agent de recouvrement en alternance H/F - Gennevilliers',
#  'Coordinateur(trice) Transports internationaux H/F',
#  'Assistant de direction en alternance SEPT 2024 (MEUDON - 92) H/F',
#  'Assistant(e) gouvernant(e) (H/F)',
#  'Gestionnaire de projet international (H/F)',
#  'Alternance - Chargé de missions QSE/RSE - H/F',
#  'Chef de bord des TGV internationaux - bilingue allemand (F ou H), Paris Est',
#  'ALTERNANCE - Appui contrôle de gestion',
#  "Assistant d'exploitation (H/F) - EN CONTRAT D'ALTERNANCE",
#  'Alternance Chargé(e) de Sécurité des SI - H/F',
#  'Gestionnaire Service Clients International H/F',
#  'Assistant de direction en alternance (Courbevoie - 92) H/F',
#  'Alternant(e) Commercial Export (H/F)',
#  'ALTERNANCE - MONTEUR(SE) RÉSEAUX ELECTRIQUES (HF) ...',
#  'Responsable commercial France / international (H/F)',
#  'Assistant administratif - Arnas H/F',
#  "ou un Educateur d'internat F/H",
#  'ALTERNANCE - Appui contrôle de gestion',
#  'Coordinateur pédagogique - Malataverne H/F',
#  'Alternant Agent de transit aérien H/F',
#  'CPAM - Alternance - Assistant de Direction H/F - 93',
#  'Chargé commercial export en alternance - Paris',
#  'Responsable commercial France / international (H/F)',
#  'Agent de voyage (alternance) - H/F',
#  'Assistant(e) gouvernant(e) (H/F)',
#  'Alternant animateur prévention et sécurité (F/H)',
#  'Chargé de projet modernisation des process MDPH (H/F)',
#  'Alternance - Assistant Community Manager (H/F) MEDIATOON LICENSING',
#  'Chargé de recrutement (alternance) F/H',
#  'AGS Le Mans - Commercial Chargé de Clientèle Internationel',
#  'Alternance - Assistant Community Manager (H/F) MEDIATOON LICENSING',
#  'Alternant(e) Commercial Export (H/F)',
#  "Chargé d'Etudes Inclusion numérique en Alternance (H/F)",
#  'ALTERNANT MONTEUR TÉLÉCOM CUIVRE (H/F)',
#  'Assistant RH en alternance H/F',
#  "ALTERNANT TECHNICIEN SURETÉ EN BUREAU D'ÉTUDES",
#  'ALTERNANT ASSISTANT MARKETING ET COMMUNICATION – ALTERNANCE (H/F)',
#  'Manager en Alternance (RH)',
#  'RESPONSABLE COMMUNICATION INTERNE',
#  "Alternant(e) chargé(e) d'ingénierie de formation H/F",
#  'Coordinateur(trice) Transports internationaux H/F',
#  'Alternance - Assistant Community Manager (H/F) MEDIATOON LICENSING',
#  'Alternant(e) Commercial Export (H/F)',
#  'Chef de bord des TGV internationaux - bilingue allemand (F ou H), Paris Est',
#  'Manager en Alternance (RH)',
#  'Chargé de recrutement (alternance) F/H',
#  'Chargé de recrutement (alternance) F/H',
#  'Assistant RH en alternance H/F',
#  'Consultant : Digital Learning F/H',
#  "Chargé d'affaires international H/F",
#  'ALTERNANCE - MONTEUR(SE) RÉSEAUX ELECTRIQUES (HF) ...',
#  'MAGASINIER PIECES DE RECHANGE ET ACCESSOIRES AUTOMOBILES EN ALTERNANCE - CITROEN LANNION H/F',
#  'ALTERNANCE MONTEUR RÉSEAUX',
#  'Alternance 3j/2j Contrôle Gestion Opérations H/F',
#  'Chargé administratif du service relations internationales F/H',
#  "Acheteur - contrat d'alternance H/F",
#  'AGS Le Mans - Commercial Chargé de Clientèle Internationel',
#  'Agent administratif en alternance H/F',
#  "ALTERNANT TECHNICIEN SURETÉ EN BUREAU D'ÉTUDES",
#  'AIDE MATERNELLE (H/F)',
#  'ALTERNANCE - TECHNICIEN(NE) VIDEOSURVEILLANCE (H/F...',
#  'ALTERNANCE - TECHNICIEN TELECOM RADIO ILE DE FRANCE H/F',
#  "ALTERNANT TECHNICIEN SURETÉ EN BUREAU D'ÉTUDES",
#  'CPAM - Alternance - Assistant de Direction H/F - 93',
#  'ALTERNANT(S) HSE F/H',
#  'ALTERNANCE - Appui contrôle de gestion',
#  'RESPONSABLE COMMUNICATION INTERNE',
#  'Agent de recouvrement en alternance H/F - Gennevilliers',
#  'TECHNICIEN SERVICE APRÈS-VENTE À L’INTERNATIONAL H/F',
#  'ALTERNANCE - ASSISTANT(E) ADV (H/F)',
#  'Chargé ADV international (H/F)',
#  "Acheteur - contrat d'alternance H/F",
#  'ALTERNANT ASSISTANT MARKETING ET COMMUNICATION – ALTERNANCE (H/F)',
#  "Alternant : Agent(e) centre de relation clients et d'information voyageurs F/H 1",
#  "Chargé d'affaires international H/F",
#  'Chargé commercial export en alternance - Paris',
#  "Agent(e) d'Escale Ferroviaire en gare de Saverne",
#  'AIDE MATERNELLE (H/F)',
#  "Alternant - Agent d'Exploitation (F/H) à Lille",
#  'Assistant RH en alternance H/F',
#  'Assistant Magasin (H/F) - En ALTERNANCE',
#  'Alternance 3j/2j Contrôle Gestion Opérations H/F',
#  'Alternant Gestionnaire Administratif F/H',
#  'Agent administratif en alternance H/F',
#  'chef de projet en alternance HF',
#  'Alternance Chargé(e) de Sécurité des SI - H/F',
#  "ou un Educateur d'internat F/H",
#  'Chargé de recrutement (alternance) F/H',
#  'Alternant Agent de transit aérien H/F',
#  'Alternant(e) Commercial Export (H/F)',
#  'Supply & Procurement Strategy Intern',
#  'Chargé(e) de communication externe et institutionnelle - CDI F/H',
#  'Internal Control Officer Junior',
#  'Chargé Qualité & RSE F/H Alternance',
#  'Chargé ADV international (H/F)',
#  'ALTERNANT ELECTRICIEN ECLAIRAGE PUBLIC (H/F)',
#  'ALTERNANT PRÉVENTEUR SANTÉ SÉCURITÉ H/F',
#  "Alternant - Agent d'Exploitation (F/H) à Lille",
#  'Coordinateur(trice) Transports internationaux H/F',
#  'Chef de bord des TGV internationaux - bilingue allemand (F ou H), Paris Est',
#  "Acheteur - contrat d'alternance H/F",
#  "Alternant(e) chargé(e) d'ingénierie de formation H/F",
#  'Agent administratif en alternance H/F',
#  'Alternance - Chargé.e de mission QSE F/H',
#  'AGENT LOGISTIQUE en alternance - H/F',
#  "Agent(e) d'Escale Ferroviaire en gare de Saverne",
#  'OPTICIEN (NE) BTS OU LICENCE ALTERNANCE',
#  'Alternant(e) Commercial Export (H/F)',
#  'Assistant RH en alternance H/F',
#  'Responsable communication interne F/H/X',
#  'ALTERNANT PRÉVENTEUR SANTÉ SÉCURITÉ H/F',
#  'CHARGE / CHARGEE DE CLIENTELE PARTICULIERS - TAVERNY (H/F)',
#  'ALTERNANT ASSISTANT MARKETING ET COMMUNICATION – ALTERNANCE (H/F)',
#  'CPAM - Alternance - Assistant de Direction H/F - 93',
#  'Agent de recouvrement en alternance H/F - Gennevilliers',
#  'Alternance Chargé(e) de Sécurité des SI - H/F',
#  'CHARGE / CHARGEE DE CLIENTELE PARTICULIERS - TAVERNY (H/F)',
#  'Gestionnaire Service Clients International H/F',
#  'Agent de Transit Maritime (F/H) - alternant',
#  'Chargé administratif du service relations internationales F/H',
#  'Gestionnaire Service Clients International H/F',
#  'Agent administratif en alternance H/F',
#  'Chargé administratif du service relations internationales F/H',
#  'Alternant animateur prévention et sécurité (F/H)',
#  'Internal Control Officer Junior',
#  'Agent administratif en alternance H/F',
#  'ALTERNANT ASSISTANT MARKETING ET COMMUNICATION – ALTERNANCE (H/F)',
#  'Responsable commercial France / international (H/F)',
#  'Supply & Procurement Strategy Intern',
#  'chef de projet en alternance HF',
#  'Gestionnaire fournisseurs achats H/F',
#  'Agent commercial vente automobile (H/F) (Tournai Belgique)',
#  "Chargé d'affaires international H/F",
#  'chef de projet en alternance HF',
#  'Chargé de recrutement (alternance) F/H',
#  'Agent administratif en alternance H/F',
#  'ALTERNANCE - Souscripteur en Retraite Collective H/F',
#  'chef de projet en alternance HF',
#  'Recruteur SPANISH Alternance h/f',
#  'Agent de voyage (alternance) - H/F',
#  'ALTERNANT CHAUFFEUR TP (H/F)',
#  "Alternant(e) Attaché(e) d'Exploitation (H/F)",
#  'Alternant Gestionnaire Administratif F/H',
#  'Supply & Procurement Strategy Intern',
#  'Chargé commercial export en alternance - Paris',
#  'ALTERNANCE TECHNICIEN EN SYSTÈMES SURETÉ',
#  'AGENT LOGISTIQUE en alternance - H/F',
#  'Agent administratif en alternance H/F',
#  'Consultant : Digital Learning F/H',
#  'Assistant chef de projet international - H/F',
#  'Chef de bord des TGV internationaux - bilingue allemand (F ou H), Paris Est',
#  "Agent(e) d'Escale Ferroviaire en gare de Saverne",
#  'Agent de comptoir polyvalent - Alternance - Thionville H/F',
#  'Chargé commercial export en alternance - Paris',
#  'Alternance - Assistant Community Manager (H/F) MEDIATOON LICENSING',
#  'Alternant animateur prévention et sécurité (F/H)',
#  'Alternant animateur prévention et sécurité (F/H)',
#  "Alternant - Agent d'Exploitation (F/H) à Lille",
#  'Responsable communication interne F/H/X',
#  'ALTERNANT MONTEUR DE RÉSEAUX ELECTRIQUES AÉRO-SOU...',
#  'Responsable commercial France / international (H/F)',
#  'Agent de recouvrement en alternance H/F - Gennevilliers',
#  'Alternant(e) Data Compliance officer - H/F H/F',
#  'INGENIEUR COMMERCIAL (Alternance) F/H',
#  'ALTERNANCE GESTION COMMERCIALE / ASSISTANT COMMERCIAL - H/F',
#  'Alternant Commercial B to B - Dépt 29 et 56 H/F',
#  'Alternance Assistant commercial H/F - BALMA',
#  'Alternance Communication commerciale & Marque',
#  'Alternance "Support équipe Avant-Vente Infrastructure & Service IT" (H/F)',
#  'Alternance - International Business Development F/H',
#  'Alternance 2024 - conseiller clientèle au sein du secteur relation à distance (H/F)',
#  'Ingénieur commercial B to B Colis International Logistique',
#  'Chargée de Recrutement et de planification en Alternance H/F',
#  'ALTERNANCE ASSISTANT(E) ADMINISTRATIF',
#  'Alternant - Chargé de projets RSE Café Zone Europe H/F',
#  "CHARGÉ-E D'AFFAIRES INTERNATIONALES",
#  'Alternance 2024 - conseiller clientèle au sein du secteur relation à distance (H/F)',
#  'Apprenti Responsable Service Client France en Alternance Colombe (92) (F/H) en Alternance',
#  'ALTERNANT(E) MARKETING ET COMMERCIAL F/H',
#  'Alternant Communication Commerciale Rennes H/F',
#  'Employé Service Client en Alternance H/F METZ • Alternance',
#  'Agent administratif en alternance H/F',
#  'Alternance - Assistant.e de direction - Septembre 2024',
#  'Alternance - E-commerce & Marketplaces - Octobre 2024 (H/F)',
#  'Alternance 2024 Apprenti Information Security Officer',
#  'ALTERNANCE PROJECT MANAGEMENT OFFICE F/H',
#  '[ALTERNANCE] Commercial(e)',
#  'Commercial Transport International (H/F) Rouen',
#  'Conseiller clientèle en alternance',
#  'ALTERNANCE POUR UN POSTE DE DEVELOPPEMENT COMMERCIAL',
#  'Alternant(e) Commercial Export (H/F)',
#  'CHARGE(E) DES ADMISSIONS INTERNATIONNALES',
#  'Gestionnaire Flux et Moyens de Paiement (H/F) Alternance – 12 mois',
#  'CONSEILLER COMMERCIAL BMW Motorrad (H/F) - BMW MINI BAYERN AVENUE',
#  'Apprenti Animateur QHSE (F/H) en Alternance',
#  'ALTERNANCE - Assistant administratif F-H',
#  'Assistant(e) de direction en alternance',
#  'Alternance Assistant commercial H/F - LYON',
#  'ALTERNANCE - ASSISTANT / ASSISTANTE ACQUISITIONS PROGRAMMES - (F/H/X)',
#  'AGS Montpellier - Coordinateur Chargé de Clientèle Internationale',
#  'ALTERNANCE – Attaché Commercial Aveda (H/F)',
#  'Alternance - Chef de projet Grands Comptes Junior H/F',
#  'Social Media Manager ALTERNANCE H/F',
#  'ALTERNANT(E) ASSISTANT(E) COMMERCIAL B2B',
#  'Responsable Commercial en Alternance (12 ou 24 mois)',
#  'Alternance - Project Manager Officer (PMO) H/F',
#  'Alternant(e) - Commercial(e) sédentaire - SERVICE AUX ENTREPRISES',
#  'Spécialiste des Opérations Internationales H/F',
#  'ALTERNANT COMMERCIAL SEDENTAIRE H/F',
#  'ALTERNANT - CHARGE DE MISSIONS ACHAT TRANSPORT AMONT',
#  'Secrétaire commerciale h/f - alternance',
#  'Alternance - Analyste Commercial H/F',
#  'Alternant(e) - Commercial(e) sédentaire - SERVICE AUX ENTREPRISES',
#  'Alternant SAV Smart Home',
#  'Alternant(e) Contrôle de gestion commercial F/H H/F',
#  'Alternant(e) Commercial(e) - Chargé(e) de développement commercial B to B (F/H)',
#  'Alternance - comptabilite / administration (H/F)',
#  'Conseiller clientèle en alternance',
#  'Apprenti Animateur QHSE (F/H) en Alternance',
#  'Assistant Comptable en alternance - Lyon',
#  'Alternance – Assistant Commercial F/H',
#  'CHARGE(E) DES ADMISSIONS INTERNATIONNALES',
#  'Alternance - E-commerce & Marketplaces - Octobre 2024 (H/F)',
#  'Ingénieur commercial B to B Colis International Logistique',
#  'Alternance - Assistant Commercial - H/F',
#  'Employé Logistique H/F - CDI 25H - Montparnasse',
#  'Assistant administratif - Arnas H/F',
#  'Alternant(e) Contrôle de gestion commercial F/H H/F',
#  'Alternance Gestionnaire client H/F',
#  'Assistante commercial (H/F) – Alternance – Noisy Le Grand (93)',
#  'Alternance - E-commerce & Marketplaces - Octobre 2024 (H/F)',
#  'Alternant Commercial H/F - (31)',
#  'ALTERNANT(E) ASSISTANT(E) COMMERCIAL B2B',
#  'Alternant(e) Commercial',
#  'Apprenti Responsable Service Client France en Alternance Colombe (92) (F/H) en Alternance',
#  'CHARGE(E) DES ADMISSIONS INTERNATIONNALES',
#  'Commercial en Alternance H/F',
#  'Adjoint de direction en alternance H/F',
#  "CHARGÉ-E D'AFFAIRES INTERNATIONALES",
#  'Conseiller clientèle en alternance',
#  "CHARGÉ-E D'AFFAIRES INTERNATIONALES",
#  'International Payroll Officer',
#  'ALTERNANCE POUR UN POSTE DE DEVELOPPEMENT COMMERCIAL',
#  'Assistant(e) commercial(e) & Administratif(ve) en alternance',
#  'KERING Venture Analyst Intern (stage)',
#  'KERING Venture Analyst Intern (stage)',
#  'Internship - Compliance Officer (H/F) - March 2025',
#  'Internship - Compliance Officer (H/F) - March 2025',
#  'Registered Nurse/Registered Psychiatric Nurse (RN & RPN), Emergency Department / Mental Health – BC Children’s Hospital',
#  'Senior Director, Learning & Development / Directeur(trice) principal(e), Formation et développement',
#  'RN / RPN',
#  'Registered Nurse/Registered Psychiatric Nurse (RN & RPN), Emergency Department / Mental Health – BC Children’s Hospital',
#  'Registered Nurse (RN), Cancer Care - BC Cancer Prince George',
#  'Home Care Aide – Ongoing Recruitment (External)',
#  'Overnight Youth Worker',
#  'Registered Nurse (RN)/ Registered Psychiatric Nurse (RPN), Looking Glass Residence - BC Children’s Hospital',
#  'Registered Nurse (RN)/ Registered Psychiatric Nurse (RPN), Looking Glass Residence - BC Children’s Hospital',
#  'Personal Support Worker Ongoing Recruitment (External)',
#  'Intern and Registered Architects',
#  'Registered Nurse (RN) - Endoscopy/Brachytherapy PARR, RT Program - BC Cancer - Vancouver',
#  'RN / RPN',
#  'Internal Medicine',
#  'Internal Medicine',
#  'Registered Nurse (RN) - BC Cancer - Multiple Locations',
#  'General Internal Medicine Physician - Leukemia/Bone Marrow Transplant Program - BC Cancer - Vancouver',
#  'Childcare for Family in California',
#  'RN / RPN',
#  'Childcare for Family in California',
#  'Internal Medicine',
#  'Personal Support Worker Evenings & Weekends Ongoing Recruitment (External)',
#  'Maamwizing Research Projects Coordinator - NOHFC Intern Opportunity',
#  'Internal Medicine',
#  'Internal Medicine',
#  'Registered Nurse/Registered Psychiatric Nurse (RN & RPN), Emergency Department / Mental Health – BC Children’s Hospital',
#  'Community Nurse RN/ LPN (8hr DAYS / NIGHTS -pediatric 1:1)',
#  'Internal Medicine',
#  'Senior Director, Learning & Development / Directeur(trice) principal(e), Formation et développement',
#  'Childcare for Family in California',
#  'RN/RPN, CRESST',
#  'Internal Medicine',
#  'Accounts Payable Clerk (Temporary Maternity Leave Coverage)',
#  'Intern and Registered Architects',
#  'Internal Medicine',
#  'Intern and Registered Architects',
#  'Internal Medicine',
#  'Personal Support Worker Evenings & Weekends Ongoing Recruitment (External)',
#  'Internal Medicine',
#  'Intern and Registered Architects',
#  'Intern and Registered Architects',
#  'Overnight Youth Worker',
#  'Internal Medicine',
#  'Accounts Payable Clerk (Temporary Maternity Leave Coverage)',
#  'Registered Nurse (RN) - Endoscopy/Brachytherapy PARR, RT Program - BC Cancer - Vancouver',
#  'Home Care Aide – Ongoing Recruitment (External)',
#  'Overnight Youth Worker',
#  'Registered Nurse/Registered Psychiatric Nurse (RN & RPN), Emergency Department / Mental Health – BC Children’s Hospital',
#  'Registered Nurse (RN)/ Registered Psychiatric Nurse (RPN), BC Children’s Mental Health - BC Children’s Hospital',
#  'Internal Medicine',
#  'Internal Medicine',
#  'Community Nurse RN/ LPN (8hr DAYS / NIGHTS -pediatric 1:1)',
#  'Personal Support Worker Evenings & Weekends Ongoing Recruitment (External)',
#  'General Internal Medicine Physician - Leukemia/Bone Marrow Transplant Program - BC Cancer - Vancouver',
#  'Senior Director, Learning & Development / Directeur(trice) principal(e), Formation et développement',
#  'Senior Director, Learning & Development / Directeur(trice) principal(e), Formation et développement',
#  'Intern and Registered Architects',
#  'Summer 2025 Internship',
#  'Internal Medicine',
#  'Personal Support Worker Evenings & Weekends Ongoing Recruitment (External)',
#  'Childcare for Family in California',
#  'Home Care Aide – Ongoing Recruitment (External)',
#  'RN / RPN',
#  'Overnight Youth Worker',
#  'Registered Nurse (RN) - Endoscopy/Brachytherapy PARR, RT Program - BC Cancer - Vancouver',
#  'Registered Nurse (RN)/ Registered Psychiatric Nurse (RPN), Looking Glass Residence - BC Children’s Hospital',
#  'Personal Support Worker Ongoing Recruitment (External)',
#  'Community Nurse RN/ LPN (8hr DAYS / NIGHTS -pediatric 1:1)',
#  'Maamwizing Research Projects Coordinator - NOHFC Intern Opportunity',
#  'Maamwizing Research Projects Coordinator - NOHFC Intern Opportunity',
#  'Personal Support Worker Ongoing Recruitment (External)',
#  'Registered Nurse (RN) - BC Cancer - Multiple Locations',
#  'Community Nurse RN/ LPN (8hr DAYS / NIGHTS -pediatric 1:1)',
#  'Intern and Registered Architects',
#  'Senior Director, Learning & Development / Directeur(trice) principal(e), Formation et développement',
#  'Maamwizing Research Projects Coordinator - NOHFC Intern Opportunity',
#  'Internal Medicine',
#  'Maamwizing Research Projects Coordinator - NOHFC Intern Opportunity',
#  'Registered Nurse (RN)/ Registered Psychiatric Nurse (RPN), Looking Glass Residence - BC Children’s Hospital',
#  'Childcare for Family in California',
#  'Registered Nurse (RN)/ Registered Psychiatric Nurse (RPN), BC Children’s Mental Health - BC Children’s Hospital',
#  'Personal Support Worker Evenings & Weekends Ongoing Recruitment (External)',
#  'Summer 2025 Internship',
#  'Senior Director, Learning & Development / Directeur(trice) principal(e), Formation et développement',
#  'Registered Nurse (RN), Cancer Care - BC Cancer Prince George',
#  'Actuarial Analyst – 2025 Internship',
#  'Actuarial Analyst - 4 Month Co-op/Internship (Fall 2025)',
#  'Actuarial Intern',
#  'Early Careers: Intern, Actuarial Consulting, Retirement (Winter, Summer or Fall 2025) – Montreal',
#  'Actuarial Services Consulting Intern - Fall 2025',
#  'Actuarial Analyst - 4 Month Co-op/Internship (Fall 2025)',
#  'Early Careers: Actuarial Internships - Winnipeg',
#  'Actuarial Intern - Summer 2025 ON',
#  'Early Careers: Actuarial Internships - Winnipeg',
#  'Early Careers: Retirement Actuarial Delivery Group Internship (Winter, Summer or Fall 2025) – Montreal',
#  'Early Careers: Actuarial Intern, Property & Casualty Reinsurance - 8 month work term (Winter and Fall 2025)',
#  'TDI Actuarial Intern/Co-op (Winter 2025)',
#  '2025 Winter - GRM, Actuarial Analyst Intern (8 Months)',
#  'Actuarial Services Consulting Intern - Fall 2025',
#  'Actuarial Analyst - 4 Month Co-op/Internship (Winter 2025)',
#  'Summer Internship - Actuarial Services - 2025',
#  'Actuarial Co-op/Intern',
#  'Actuarial Analyst, Valuation, Winter 2025 (Co-op/Internship) - 4 Months',
#  'Early Careers: Intern, Actuarial Consulting, Retirement (Winter, Summer or Fall 2025) – Montreal',
#  'Actuarial Analyst, Summer 2025 internship',
#  'Early Careers: Health and Benefits Internship – Winter, Summer, Fall 2025 - Montreal',
#  'Actuarial Intern (Fall 2024)',
#  'Early Careers: Health and Benefits Internship – Winter, Summer, Fall 2025 - Montreal',
#  'Early Careers: Health and Benefits Internship – Winter, Summer, Fall 2025 - Montreal',
#  'Actuarial Services Consulting Intern - Fall 2025',
#  'Actuarial Intern (Graduates) - London',
#  'Early Careers: Retirement Actuarial Internship – Winter, Summer or Fall 2025 – Vancouver & Calgary',
#  'Early Careers: Retirement Actuarial Internship – Winter, Summer or Fall 2025 – Vancouver & Calgary',
#  'Actuarial Co-op/Intern',
#  'Actuarial Intern - Summer 2025 ON',
#  'TDI Actuarial Intern/Co-op (Winter 2025)',
#  'Actuarial Intern - Summer 2025 ON',
#  'Actuarial Intern (Fall 2024)',
#  'Early Careers: Intern, Actuarial Consulting, Retirement (Winter, Summer or Fall 2025) – Montreal',
#  'Early Careers: Actuarial Intern, Retirement Consulting',
#  'Early Careers: Actuarial Internships - Winnipeg',
#  'Early Careers: Actuarial Internships - Winnipeg',
#  'Été 2025 Stage en audit interne - profil comptabilité ou actuariat',
#  'Actuarial Intern (Graduates) - London',
#  'Early Careers: Actuarial Intern, Retirement Consulting',
#  '2025 Winter - GRM, Actuarial Analyst Intern (8 Months)',
#  'Early Careers: Retirement Actuarial Internship – (Winter, Summer, Fall 2025) – Toronto',
#  'Actuarial Intern (Fall 2024)',
#  'Actuarial Intern (Graduates) - London',
#  'Early Careers: Retirement Actuarial Delivery Group Internship (Winter, Summer or Fall 2025) – Montreal',
#  'Actuarial Co-op/Intern',
#  'Early Careers: Retirement Actuarial Internship – (Winter, Summer, Fall 2025) – Toronto',
#  'Early Careers: Retirement Actuarial Internship – (Winter, Summer, Fall 2025) – Toronto',
#  'Actuarial Analyst, Valuation, Winter 2025 (Co-op/Internship) - 4 Months',
#  'Early Careers: Health and Benefits Internship – Winter, Summer, Fall 2025 - Montreal',
#  'Actuarial Analyst - Winter 2025 Co-op/Intern',
#  'Actuarial Analyst - Winter 2025 Co-op/Intern',
#  'TDI Actuarial Intern/Co-op (Winter 2025)',
#  'Actuarial Intern (Graduates) - London',
#  'Actuarial Intern',
#  'Early Careers: Intern, Actuarial Consulting, Retirement (Winter, Summer or Fall 2025) – Montreal',
#  'Internship position, Actuarial or Data Science',
#  'Early Careers: Retirement Actuarial Internship – Winter, Summer or Fall 2025 – Vancouver & Calgary',
#  'Actuarial Intern (Graduates) - London',
#  '2025 Winter - GRM, Actuarial Analyst Intern (8 Months)',
#  'Early Careers: Actuarial Intern, Property & Casualty Reinsurance - 8 month work term (Winter and Fall 2025)',
#  'Actuarial Services Consulting Intern - Fall 2025',
#  'Summer Internship - Actuarial Services - 2025',
#  'Actuarial Analyst – 2025 Internship',
#  'Internship position, Actuarial or Data Science',
#  'Actuarial Analyst - Winter 2025 Co-op/Intern',
#  'Agent interne aux ventes',
#  'Intern | Procurement | Winter',
#  "Gestionnaire chaine d'approvisionnement et qualité fournisseurs",
#  'Intern | Procurement | Winter',
#  'Instacart Shopper - Choose Your Own Schedule and Start Earning',
#  'Intern | Procurement | Winter',
#  'Marchandiseur(euse) Web - Remplacement congé de maternité',
#  'Agent interne aux ventes',
#  'Intern | Procurement | Winter',
#  'Manager, Procurement Governance and Compliance',
#  'Intern | Procurement | Winter',
#  'Manager, Turnaround Procurement',
#  'Manager, Sourcing Global External Supply Operations',
#  'Winter Intern, Procurement',
#  'Winter Intern, Procurement',
#  'Technology Vendor Governance & Procurement Analyst',
#  'Intern | Procurement | Winter',
#  'Senior Turnaround Contracts and Procurement Analyst (Contract)',
#  'Adjoint(e) administratif(ve) ou stagiaire adjoint(e) administratif(ve) Remplacement congé de materni',
#  'Directeur(trice) adjoint(e) aux communications internes',
#  'Conseillère ou conseiller en gouvernance scolaire',
#  'Stagiaire, Opérations Comptables - Intern, Accounting Operations',
#  'Adjointe administrative bilingue, Services bancaires internationaux et marchés - Montréal',
#  'Adjointe administrative bilingue, Services bancaires internationaux et marchés - Montréal',
#  'Commis à l’expédition – Commandes Internet',
#  'Technicien ou technicienne RH - Remplacement de congé de maternité (environ 10 mois)',
#  'Adjoint(e) administratif(ve) ou stagiaire adjoint(e) administratif(ve) Remplacement congé de materni',
#  'Stagiaire, Opérations Comptables - Intern, Accounting Operations',
#  'Adjoint(e) administratif(ve) ou stagiaire adjoint(e) administratif(ve) Remplacement congé de materni',
#  'Adjoint(e) administratif(ve) ou stagiaire adjoint(e) administratif(ve) Remplacement congé de materni',
#  'Stagiaire, Adjoint(e) juridique | Intern, Legal Administrative Assistant',
#  'Stagiaire, Opérations Comptables - Intern, Accounting Operations',
#  'GBM-Equity Research Associate Internship/Co-op Winter 2025',
#  'Senior Financial Analyst, Research Grants (Internally known as a Finance Partner)',
#  'Internal Medicine Sr Program Assistant, Fraser',
#  'Research Assistant Intern',
#  'Research and Administrative Assistant Intern',
#  'ESG Research Senior Analyst, Government Research',
#  'GBM-Equity Research Associate Internship/Co-op Winter 2025',
#  'Postdoctoral Researcher/Research Associate in Machine Learning and Computational Catalysis',
#  'Northern Ontario Research Assistant',
#  'Postdoctoral Researcher/Research Associate in Machine Learning and Computational Catalysis',
#  'Analyst, Tax [Research and Development & Government Incentives]',
#  'Communications and Distributed Learning Program Assistant',
#  'Research Associate - Reinforcement Learning-Based Formal Verification',
#  'Research and Administrative Assistant Intern',
#  'Research Associates/Interns/Pre-Optometry',
#  'Research Assistant Intern',
#  'Internal Medicine Sr Program Assistant, Fraser',
#  'Research Associate - Reinforcement Learning-Based Formal Verification',
#  'Senior Analyst, Tax [Research and Development & Government Incentives]',
#  'Canola Seed Production Research Summer Associate - Internship',
#  'Northern Ontario Research Assistant',
#  'Senior Financial Analyst, Research Grants (Internally known as a Finance Partner)',
#  'Senior Analyst, Tax [Research and Development & Government Incentives]',
#  'Research Assistant Intern',
#  'Northern Research Coordinator',
#  'ESG Research Senior Analyst, Government Research',
#  'Northern Research Coordinator',
#  'Communications and Distributed Learning Program Assistant',
#  'Analyst, Tax [Research and Development & Government Incentives]',
#  'Internal Medicine Sr Program Assistant, Fraser',
#  'Senior Financial Analyst, Research Grants (Internally known as a Finance Partner)',
#  'Research Associate - Reinforcement Learning-Based Formal Verification',
#  'Maamwizing Research Projects Coordinator - NOHFC Intern Opportunity',
#  'Canola Seed Production Research Summer Associate - Internship',
#  'Research Associate - Reinforcement Learning-Based Formal Verification',
#  'Maamwizing Research Projects Coordinator - NOHFC Intern Opportunity',
#  'Research Assistant Intern',
#  'Associate, Real Estate - Analytics, Research, & Governance (ARG)',
#  'Associate, Real Estate - Analytics, Research, & Governance (ARG)',
#  'Directeur, groupe de Services-conseils en gouvernance, droit et conformité (GDC) | Services de consultation en régimes de retraite',
#  'Summer 2025 Internship',
#  'Administrateur de Paie (Remplacement maternité)',
#  'Conseillère ou conseiller en gouvernance scolaire',
#  'gestionnaire de district des ventes internes / District Manager, Inside Sales',
#  'Summer 2025 Internship',
#  'gestionnaire de district des ventes externes / District Manager, Outside Sales',
#  'Consultant aux Ventes Internes',
#  'Administrateur senior de contrats fournisseurs',
#  'Learning Management System Global Administrator (12M Term)',
#  'Casual Administrative Assistant to Educational Administrator- School of Health Sciences- To Garner Applications',
#  'Branch Operations Manager - Burnaby, BC',
#  'Casual Administrative Assistant to Educational Administrator- School of Health Sciences- To Garner Applications',
#  'Learning Management System (LMS) Administrator',
#  'Warranty Administrator - Destination Toyota Burnaby',
#  'Administrator – Government Administration',
#  'Casual Administrative Assistant to Educational Administrator- School of Health Sciences- To Garner Applications',
#  'Executive Administrator, Temporary Full-Time (Maternity Leave )',
#  'Warranty Administrator - Destination Toyota Burnaby',
#  'Administrateur senior de contrats fournisseurs',
#  'Administrateur de Paie (Remplacement maternité)',
#  'Office Administrator - Maternity Leave Coverage(Temp)',
#  'Operations Administrator (Maternity Cover: 13-14 months contract)',
#  'Casual Administrative Assistant to Educational Administrator- School of Health Sciences- To Garner Applications',
#  'Marketing Administrator (Fixed Contract - Maternity Coverage)',
#  'Receptionist (Maternity Leave Contract)',
#  'Senior Analyst, External Funds Operations (19-month contract)',
#  'Senior Financial Analyst, Research Grants (Internally known as a Finance Partner)',
#  'Chief Accountant - Maternity Leave Position',
#  'Payroll and HR Coordinator (Maternity Leave Contract)',
#  'Office Administrator - Maternity Leave Coverage(Temp)',
#  'Operations Administrator (Maternity Cover: 13-14 months contract)',
#  'Casual Administrative Assistant to Educational Administrator- School of Health Sciences- To Garner Applications',
#  'Marketing Administrator (Fixed Contract - Maternity Coverage)',
#  'Receptionist (Maternity Leave Contract)',
#  'Senior Analyst, External Funds Operations (19-month contract)',
#  'Chief Accountant - Maternity Leave Position',
#  'Payroll and HR Coordinator (Maternity Leave Contract)',
#  'gestionnaire de district des ventes externes / District Manager, Outside Sales',
#  'gestionnaire de district des ventes externes / District Manager, Outside Sales',
#  'Analyste en chef, gouvernance fiscale / Lead Analyst, Tax Governance',
#  'International Student Transition Coordinator',
#  'International Student Transition Coordinator',
#  'International Student Transition Coordinator',
#  'International Student Transition Coordinator',
#  'Bridge Engineer, Western Canada',
#  'gestionnaire de district des ventes internes / District Manager, Inside Sales',
#  'gestionnaire de district des ventes internes / District Manager, Inside Sales',
#  'gestionnaire de district des ventes internes / District Manager, Inside Sales',
#  'gestionnaire de district des ventes externes / District Manager, Outside Sales',
#  'gestionnaire de district des ventes externes / District Manager, Outside Sales',
#  'gestionnaire de district des ventes externes / District Manager, Outside Sales',
#  'Commercial Mortgage Underwriting Intern (Fall 2024)',
#  'Agente ou agent de gestion du personnel – Service de la dotation interne',
#  'Agente ou agent de gestion du personnel – Service de la dotation interne',
#  'Journalier',
#  'Mgr, Financial Controls, Risk & Governance',
#  'Journalier',
#  "Regional Learning Program Liaison, Women's Health",
#  'Agent(e) de vente interne/ Inside Sales Agent',
#  'Agente ou agent de gestion du personnel – Service de la dotation interne',
#  'Chauffeur-Livreur / Représentant des ventes internes',
#  'REPRÉSENTANT SERVICE À LA CLIENTÈLE - VENTES INTERNES',
#  'Journaliste multiplateforme, Noovo info, Québec, Bell Média',
#  'Agent interne de vente',
#  'Journaliste multiplateforme, Noovo info, Québec, Bell Média',
#  "Regional Learning Program Liaison, Women's Health",
#  'Industrial / Commercial Journeyman and Apprentice Electrician',
#  'Apprentice/Journeymen Electrician - Construction',
#  'Furniture Delivery',
#  'Internal Sales Representative',
#  'Agent interne de vente',
#  "Journalier à l'assemblage",
#  'Furniture Installer',
#  'Security officer- Near Stanfield International Airport',
#  'Recruitment, Admissions & Registration Officer (Burnaby Campus)',
#  'General Manager - Western Canada',
#  'Agent(e) de vente interne/ Inside Sales Agent',
#  'Journeyman/woman Carpenter',
#  'Industrial / Commercial Journeyman and Apprentice Electrician',
#  'Temporary Full Time Corn Tester - Ingredion Canada',
#  'JOURNALIER DE PRODUCTION',
#  'Furniture Installer',
#  'Overnight Part Time Parking Officer',
#  'International Student Transition Officer (ISTO)',
#  'New Drivers: Earn a $200 bonus for 10 rides in 7 days',
#  'Commercial Banking Intern/Co-op (Winter 2025)',
#  'Vernon, BC - Pickup or Cargo Van',
#  'Journeyman & Apprentice Plumbers',
#  'Commercial Banking Intern/Co-op (Winter 2025)',
#  'Recruitment, Admissions & Registration Officer (Burnaby Campus)',
#  'citizen services officer (CSO) - government services',
#  'International Admissions Officer',
#  'citizen services officer (CSO) - government services',
#  'International Admissions Officer',
#  'Journeyman/woman Carpenter',
#  'Représentant(e) des ventes internes',
#  'Learning and Performance Advisor (YVR)',
#  'International Admissions Officer',
#  'Marketing Intern',
#  'Représentant interne',
#  'Security officer- Near Stanfield International Airport',
#  'Industrial / Commercial Journeyman and Apprentice Electrician',
#  'Electrician (Journeyman / Red Seal Or Apprentice)',
#  'Représentant(e) interne',
#  'Agent interne de vente',
#  'Agent.e de communication et de collecte de fonds (remplacement de congé de maternité)',
#  'Journeyperson Electrician - Commercial Sites',
#  'Représentant des ventes externes B2B (Montréal Sud)',
#  'Journeyman/woman Carpenter',
#  'Security officer- Near Stanfield International Airport',
#  'Furniture Installer',
#  'International Admissions Officer',
#  'General Production - Afternoon Shift',
#  'Représentant des ventes externes',
#  'Marketing Intern',
#  'Facteur - Cornwall',
#  'Agent ou agente d’éducation du public et de diffusion externe II',
#  'Alternative Program Teacher',
#  'Governance Officer',
#  'Learning and Development Trainer',
#  'Governance Assistant',
#  'Alternative Program Teacher',
#  'Executive Assistant, Governance Office',
#  'External Relations Officer/Agente ou agent des relations extérieures',
#  'Senior Policy Advisor - Indigenous Early Learning & Child Care (IELCC) -',
#  'Community Access & Transition Nurse - Registered Nurse (RN) / Registered Psychiatric Nurse (RPN), Correctional Health Services - Coquitlam, BC',
#  'Alternative Program Teacher',
#  'Senior Manager, Turnaround & Restructuring',
#  'Senior Manager, Turnaround & Restructuring',
#  'Director, Internal Audit',
#  'Intermediate Specialist, Governance',
#  'Learning and Development Trainer',
#  'Senior Manager, Turnaround & Restructuring',
#  'Senior Lead, OMAI Governance',
#  'Director, Internal Audit',
#  'Health Care Improvement Advisor, International Operations',
#  'Director, Internal Audit',
#  'LTO - 0.1 GRADE 1, DAY 5 AFTERNOON',
#  'Community Access & Transition Nurse - Registered Nurse (RN) / Registered Psychiatric Nurse (RPN), Correctional Health Services - Coquitlam, BC',
#  'Health Care Improvement Advisor, International Operations',
#  'Executive Assistant, Governance Office',
#  'Senior Policy Advisor - Indigenous Early Learning & Child Care (IELCC) -',
#  'External Relations Officer/Agente ou agent des relations extérieures',
#  'Senior Lead, OMAI Governance',
#  'Governance Officer',
#  'Alternative Program Teacher',
#  'Senior Manager, Turnaround & Restructuring',
#  'Deputy Returning Officer (DRO) - Election Engagement Strategist',
#  'LTO - 0.1 PLANNING TIME, P, DAY 1 AFTERNOON',
#  'Executive Director, Turnaround & Restructuring',
#  'Registered Nurse (RN) - New Grads!',
#  'Director, Internal Audit',
#  'Governance Officer',
#  'Registered Nurse (RN) - New Grads!']

# %%
def plot_bar_chart(df, column):
    plt.figure(figsize=(10, 6))
    for i in range(0 , df[column].nunique() , 20):
        df[column].value_counts()[i:i+20].plot(kind='bar')
        plt.show()

def plot_bar_chart_combined(df, columns):
    tab = []
    for column in columns:
        tab.append(column)
    print(tab)
    plt.figure(figsize=(10, 6))
    unique_counts = []
    for column in tab:
        unique_counts.append(df[column].nunique())
    max_unique_count = max(unique_counts)
    for i in range(0 , max_unique_count , 20):
        df[tab].value_counts()[i:i+20].plot(kind='bar')
        plt.show()

# %%
from pandasql import sqldf

# %%
plot_bar_chart(df, 'salaryInfoAndJobType')

# %%
plot_bar_chart_combined(df, ['salaryInfoAndJobType', 'country'])

# %%
df_counts = df[['jobType','salary']].value_counts()[:20].plot(kind='bar')
# df_counts.plot(kind='scatter', x='positionTitle', y='location', s=df_counts['count'] * 10)
# plt.xticks(rotation=45)
# plt.show()
df_counts

# %%
df['salary'] = df.apply(
    lambda x: "" 
    if not re.search(r'\d+', str(x['salary'])) 
    else x['salary'], 
    axis=1
)

# Afficher les 10 valeurs les plus fréquentes dans salary
df['salary'].value_counts()[:20].plot(kind='bar')

# %%
def transform_position_title(df):
    """
    This function cleans a DataFrame containing job posting information by following these steps:
    Steps:
    1. Remove dates:
    2. Remove salary rates:
    3. Remove hourly rates:
    4. Replace codes with actual position titles where possible:
    5. Rename bad encodings:
    6. Remove job type and shift/schedule information:
    7. Remove location if possible:
    Arguments:
    - df: DataFrame containing the job postings data to be cleaned.
    Returns:
    - A cleaned DataFrame according to the steps above.
    """

    # Remove dates
    date_pattern1 = r'\d{1,2}/\d{1,2}/\d{2,4}'
    date_pattern2 = r'\d{1,2}-\d{1,2}-\d{2,4}'
    date_pattern3 = r'\d{1,2}\.\d{1,2}\.\d{2,4}'
    date_pattern4 = r'\d{1,2}\s\w+\s\d{2,4}'
    date_pattern5 = r'\w+\s\d{1,2},\s\d{4}'
    date_pattern6 = r'\d{4}-\d{2}-\d{2}' "YYYY-mm-DD"
    date_patterns = [date_pattern1, date_pattern2, date_pattern3, date_pattern4, date_pattern5, date_pattern6]
    df = df.map(lambda x: re.sub(pattern, '', x) for pattern in date_patterns)

    # Remove month and year
    month_year_pattern = r'\b(janvier|january|février|february|mars|march|avril|april|mai|may|juin|june|juillet|july|août|august|septembre|september|octobre|october|novembre|november|décembre|december)\s\d{4}\b'
    df = df.map(lambda x: re.sub(month_year_pattern, '', x))

    # Remove salary rates
    pattern_salary_ca = re.compile(r'(?:De\s)?([\d\s]+)\s?\$(?:\s?à\s([\d\s]+)\s?\$\s?)(?:par\s|per\s|annuel\s|yearly\s)?(year|annum|an)\s*', re.IGNORECASE)
    pattern_salary_us = re.compile(r'(?:From\s)?\$\d+(?:,\d{3})*(?:\.\d{2})?(?:–\$\d+(?:,\d{3})*(?:\.\d{2})?)?\s?(?:a|per)\s(hour|day|week|month|year)\s*', re.IGNORECASE)
    pattern_salary_fr = re.compile(r'(?:De\s)?([\d\s]+)\s?€\s?à\s([\d\s]+)\s?€\s?(?:par\s|per\s|annuel\s|yearly\s|annum\s)?(an|year)\s*', re.IGNORECASE)
    salary_patterns = [pattern_salary_ca, pattern_salary_us, pattern_salary_fr]
    df = df.map(lambda x: re.sub(pattern, '', x) for pattern in salary_patterns)

    # Remove hourly rates
    time_units_pattern = r'\b(heure|hrs|hour|day|jour|week|semaine)\b'
    df = df.map(lambda x: re.sub(time_units_pattern, '', x))

    # Replace codes with actual position titles where possible(eg. RN -> Registered Nurse)
    
    # Rename bad encodings

    # Remove job type and shift/schedule information
    jobType_pattern = r'\b(temps\splein|full\s?time|part\s?time|temps\s?partiel|contract|contractuel|permanent|temporaire|temporary|contractual\b'
    shiftAndSchedule_pattern = r'\b(jour|day|soir|evening|nuit|night|weekend|fin\sde\ssemaine|weekend|rotating|rotatif|rotative|rotating\b'
    df = df.map(lambda x: re.sub(jobType_pattern, '', x))
    df = df.map(lambda x: re.sub(shiftAndSchedule_pattern, '', x))

    # Remove location if possible
    


    
    return df

def transform_salary_and_job_type(df):
    """
    This function processes salary and job type information in a DataFrame, ensuring consistency in language and data structure, following these steps:
    Steps:
    1. Extract salary information from combined fields:
    2. Handle missing salary information:
    3. Standardize hybrid data (language and format)
    4. Detect and translate language:
    Arguments:
    - df: DataFrame containing job posting data with salary, job type, and schedule information to be processed.
    Returns:
    - A cleaned DataFrame with standardized salary, job type, schedule, and translated information where necessary.
    """
    
    # Extract salary information from combined fields
    salary_pattern_without_symbol = r'(\d{1,3}(?:,\d{3})*|\d+)\s*-\s*(\d{1,3}(?:,\d{3})*|\d+)\s*per\s*(year|month|week|day|hour)\b'


    df[['salaryInfoAndJobType' , 'country']].map(lambda x: )



def transform_company_name(df):
    """
    This function cleans a DataFrame by identifying and removing bad encodings, specifically sequences of squares or other invalid characters in text fields (e.g., names).

    Steps:
    1. Detect bad encodings:
    2. Remove or replace bad encodings:

    Arguments:
    - df: DataFrame containing text fields where bad encodings (e.g., sequences of squares) need to be removed.

    Returns:
    - A cleaned DataFrame with bad encodings removed from text fields.


    """
    pass
def transform_location(df):
    """
    This function cleans a DataFrame by removing special characters, specifically at the beginning of text fields, and addressing bad encodings.

    Steps:
    1. Remove bad encodings:
    2. Remove special characters at the beginning of text fields:

    Arguments:
    - df: DataFrame containing text fields where bad encodings and special characters at the beginning of strings need to be removed.

    Returns:
    - A cleaned DataFrame with special characters removed from the beginnings of text fields and bad encodings corrected.
    """

# %%
def transfrom():
    x=transform_position_title(x)
    x=transform_salary_and_job_type(x)
    x=transform_salary(x)
    x=transform_company_name(x)
    x=transform_location(x)

# %%
plot_bar_chart(df, 'positionTitle')

# %% [markdown]
# #### We can see that salaries are too different we can try to put them together in intervals
